# %%
from autotarget import autotarget

searcher = autotarget.Searcher()
# Out:
# Loaded 2838579 data from file.
# 28877 disease names were extracted.

# %%
searcher.search_disease('bipolar')
# Out:
# 9 results
# {'BIPOLAR AFFECTIVE DISORDER, SUSCEPTIBILITY TO',
#  'Bipolar Disorder',
#  'Bipolar I disorder',
#  'Bipolar II disorder',
#  'Depressed bipolar I disorder',
#  'Depression, Bipolar',
#  'Mixed bipolar I disorder',
#  'Schizoaffective disorder, bipolar type',
#  'bipolar type I disorder'}

# %%
searcher.search('bipolar')
# Out:
#                  id  probability  label   Entry  \
# 0   ENSP00000437737     0.999994    1.0  P28223
# 1   ENSP00000437737     0.999994    1.0  P28223
# 2   ENSP00000266376     0.999620    1.0  Q13936
# 3   ENSP00000266376     0.999620    1.0  Q13936
# 4   ENSP00000407546     0.999066    1.0  P36544
# 5   ENSP00000290866     0.998772    1.0  P12821
# 6   ENSP00000444688     0.998373    1.0  P13637
# 7   ENSP00000226574     0.997875    1.0  P19838
# 8   ENSP00000361359     0.991609    1.0  P25942
# 9   ENSP00000278840     0.991419    1.0  O95864
# 10  ENSP00000291700     0.965602    1.0  P04271
# 11  ENSP00000266041     0.955817    1.0  Q14624
# 12  ENSP00000308741     0.916110    1.0  O15516
# 13  ENSP00000295454     0.908993    1.0  P18505
# 14  ENSP00000264318     0.863623    1.0  P48169
# 15  ENSP00000355593     0.641764    1.0  Q9NRI5
# 16  ENSP00000440045     0.506316    1.0  P16615
# 17  ENSP00000427015     0.422754    1.0  Q15349
# 18  ENSP00000418081     0.335817    1.0  Q9NY47
# 19  ENSP00000376523     0.233793    1.0  Q9NY72
# 20  ENSP00000360626     0.112369    1.0  Q9UIX4
# 21  ENSP00000241014     0.088547    1.0  Q9UQF2
#
#                                         Protein names UniProtKB  geneName  \
# 0   5-hydroxytryptamine receptor 2A (5-HT-2) (5-HT...    P28223     HTR2A
# 1   5-hydroxytryptamine receptor 2A (5-HT-2) (5-HT...    P28223     HTR2A
# 2   Voltage-dependent L-type calcium channel subun...    Q13936   CACNA1C
# 3   Voltage-dependent L-type calcium channel subun...    Q13936   CACNA1C
# 4     Neuronal acetylcholine receptor subunit alpha-7    P36544    CHRNA7
# 5   Angiotensin-converting enzyme (ACE) (EC 3.4.15...    P12821       ACE
# 6   Sodium/potassium-transporting ATPase subunit a...    P13637    ATP1A3
# 7   Nuclear factor NF-kappa-B p105 subunit (DNA-bi...    P19838     NFKB1
# 8   Tumor necrosis factor receptor superfamily mem...    P25942      CD40
# 9   Acyl-CoA 6-desaturase (EC 1.14.19.3) (Delta(6)...    O95864     FADS2
# 10  Protein S100-B (S-100 protein beta chain) (S-1...    P04271     S100B
# 11  Inter-alpha-trypsin inhibitor heavy chain H4 (...    Q14624     ITIH4
# 12  Circadian locomoter output cycles protein kapu...    O15516     CLOCK
# 13  Gamma-aminobutyric acid receptor subunit beta-...    P18505    GABRB1
# 14  Gamma-aminobutyric acid receptor subunit alpha...    P48169    GABRA4
# 15               Disrupted in schizophrenia 1 protein    Q9NRI5     DISC1
# 16  Sarcoplasmic/endoplasmic reticulum calcium ATP...    P16615    ATP2A2
# 17  Ribosomal protein S6 kinase alpha-2 (S6K-alpha...    Q15349   RPS6KA2
# 18  Voltage-dependent calcium channel subunit alph...    Q9NY47  CACNA2D2
# 19                      Sodium channel subunit beta-3    Q9NY72     SCN3B
# 20  Potassium voltage-gated channel subfamily G me...    Q9UIX4     KCNG1
# 21  C-Jun-amino-terminal kinase-interacting protei...    Q9UQF2  MAPK8IP1
#
#              pLI    DSI    DPI                             diseaseName
# 0   5.112400e-01  0.472  0.846  Schizoaffective disorder, bipolar type
# 1   5.112400e-01  0.472  0.846                Mixed bipolar I disorder
# 2   1.000000e+00  0.510  0.846            Depressed bipolar I disorder
# 3   1.000000e+00  0.510  0.846                 bipolar type I disorder
# 4   4.154900e-04  0.532  0.654  Schizoaffective disorder, bipolar type
# 5   1.034400e-37  0.328  0.923                Mixed bipolar I disorder
# 6   1.000000e+00  0.544  0.615                Mixed bipolar I disorder
# 7   1.000000e+00  0.396  0.923  Schizoaffective disorder, bipolar type
# 8   8.460300e-01  0.396  0.846  Schizoaffective disorder, bipolar type
# 9   9.981500e-01  0.575  0.692            Depressed bipolar I disorder
# 10  4.387000e-02  0.383  0.923                Mixed bipolar I disorder
# 11  6.435200e-13  0.559  0.769            Depressed bipolar I disorder
# 12  9.995700e-01  0.463  0.885                Mixed bipolar I disorder
# 13  9.811600e-01  0.686  0.500  Schizoaffective disorder, bipolar type
# 14  7.786000e-01  0.751  0.308  Schizoaffective disorder, bipolar type
# 15  1.675600e-06  0.548  0.769  Schizoaffective disorder, bipolar type
# 16  9.994500e-01  0.529  0.808            Depressed bipolar I disorder
# 17  9.407300e-03  0.636  0.538            Depressed bipolar I disorder
# 18  9.999700e-01  0.626  0.615            Depressed bipolar I disorder
# 19  5.103000e-02  0.686  0.269  Schizoaffective disorder, bipolar type
# 20  2.624300e-02  0.890  0.077            Depressed bipolar I disorder
# 21  9.998300e-01  0.716  0.462            Depressed bipolar I disorder
